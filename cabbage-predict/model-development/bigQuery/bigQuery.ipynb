# %%
pip install --upgrade google-cloud-bigquery
# Out:
# Collecting google-cloud-bigquery
#   Downloading google_cloud_bigquery-2.24.0-py2.py3-none-any.whl (198 kB)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\cdy16\anaconda3\lib\site-packages (from google-cloud-bigquery) (2.25.1)
# Requirement already satisfied: packaging>=14.3 in c:\users\cdy16\anaconda3\lib\site-packages (from google-cloud-bigquery) (20.9)
# Collecting grpcio<2.0dev,>=1.38.1
#   Downloading grpcio-1.39.0-cp38-cp38-win_amd64.whl (3.2 MB)
# Collecting google-cloud-core<3.0.0dev,>=1.4.1
#   Downloading google_cloud_core-1.7.2-py2.py3-none-any.whl (28 kB)
# Collecting proto-plus>=1.10.0
#   Downloading proto_plus-1.19.0-py3-none-any.whl (42 kB)
# Collecting google-resumable-media<3.0dev,>=0.6.0
#   Downloading google_resumable_media-1.3.3-py2.py3-none-any.whl (75 kB)
# Collecting google-api-core[grpc]<3.0.0dev,>=1.29.0
#   Downloading google_api_core-1.31.2-py2.py3-none-any.whl (93 kB)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.17.3-cp38-cp38-win_amd64.whl (909 kB)
# Requirement already satisfied: pytz in c:\users\cdy16\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.29.0->google-cloud-bigquery) (2021.1)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
# Requirement already satisfied: six>=1.13.0 in c:\users\cdy16\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.29.0->google-cloud-bigquery) (1.15.0)
# Collecting google-auth<2.0dev,>=1.25.0
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\cdy16\anaconda3\lib\site-packages (from google-api-core[grpc]<3.0.0dev,>=1.29.0->google-cloud-bigquery) (52.0.0.post20210125)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.1.2-cp38-cp38-win_amd64.whl (34 kB)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\cdy16\anaconda3\lib\site-packages (from google-crc32c<2.0dev,>=1.0->google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\cdy16\anaconda3\lib\site-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0->google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\cdy16\anaconda3\lib\site-packages (from packaging>=14.3->google-cloud-bigquery) (2.4.7)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\cdy16\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-bigquery) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\cdy16\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-bigquery) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\cdy16\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-bigquery) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cdy16\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-bigquery) (2020.12.5)
# Installing collected packages: pyasn1, rsa, pyasn1-modules, protobuf, cachetools, googleapis-common-protos, google-auth, grpcio, google-crc32c, google-api-core, proto-plus, google-resumable-media, google-cloud-core, google-cloud-bigquery
# Successfully installed cachetools-4.2.2 google-api-core-1.31.2 google-auth-1.35.0 google-cloud-bigquery-2.24.0 google-cloud-core-1.7.2 google-crc32c-1.1.2 google-resumable-media-1.3.3 googleapis-common-protos-1.53.0 grpcio-1.39.0 proto-plus-1.19.0 protobuf-3.17.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 rsa-4.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.cloud import bigquery

# Construct a BigQuery client object.
client = bigquery.Client()

query = """
    SELECT * FROM `sixth-tempo-323301.test_poc_dataset.cabbage-predict` LIMIT 1000
"""

#From 프로젝트명.데이터세트명.테이블명

df = client.query(query).to_dataframe()

df
# Out:
#          year  avgTemp  minTemp  maxTemp  rainFall  avgPrice
# 0    20121205      0.0     -3.8      5.4       6.7      2600
# 1    20130204      2.0     -1.6      6.3       4.2      3702
# 2    20110301      2.5     -0.4      5.6       3.2      4710
# 3    20151203      3.0     -0.3      6.5       3.0      2240
# 4    20160228      4.0     -0.5     10.5       5.8      3147
# ..        ...      ...      ...      ...       ...       ...
# 995  20141218     -5.3    -10.1      0.4       0.0      1910
# 996  20101110      5.8      0.2     12.3       0.0      3079
# 997  20110318      5.8     -3.6     13.8       0.0      4824
# 998  20130310      5.8      0.4     13.9       0.0      4076
# 999  20110127     -5.8    -10.5     -0.5       0.0      5234
#
# [1000 rows x 6 columns]

# %%
# !pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-5.0.0-cp38-cp38-win_amd64.whl (14.5 MB)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\cdy16\anaconda3\lib\site-packages (from pyarrow) (1.20.1)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-5.0.0
